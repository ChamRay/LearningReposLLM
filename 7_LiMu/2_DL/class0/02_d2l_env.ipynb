# %%
import subprocess
import sys

packages = [
    "numpy",
    "pandas",
    "matplotlib",
    "scikit-learn",
    "tqdm",
    "pillow",
    "ultralytics",
    "d2l",
]

subprocess.run(
    [sys.executable, "-m", "pip", "install", "-U", *packages],
    check=True
)

print("All Python dependencies installed.")
