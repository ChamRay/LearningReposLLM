# %%
import torch

A = torch.arange(20).reshape(5,4)
A

# %%
A.T

# %%
B = torch.tensor([[1,2,3],[2,0,4],[3,4,5]])

B,B.T==B

# %%
A = torch.arange(20,dtype=torch.float32).reshape(5,4)

B = A.clone()

A,A+B

# %%
A * B

# %%
a = 2
X = torch.arange(24).reshape(2,3,4)
a+X,(a*X).shape

# %%
x = torch.arange(4,dtype=torch.float32)

x , x.sum()

# %%
A = torch.arange(20*2).reshape(2,5,4)
A,A.shape

# %%
A_sum_axis0 = A.sum(axis=0)
A_sum_axis0,A_sum_axis0.shape

# %%
A_sum_axis1 = A.sum(axis=1)
A_sum_axis1,A_sum_axis1.shape

# %%
A_sum_axis2 = A.sum(axis=2)
A_sum_axis2,A_sum_axis2.shape

# %%
A = torch.arange(20,dtype=torch.float32).reshape(5,4)
A.shape,A.sum()

# %%
A.mean(dtype=torch.float32),A.sum()/A.numel()

# %%
A.mean(axis=0,dtype=torch.float32),A.sum(axis=0,dtype=torch.float32)/A.shape[0]

# %%
sum_A = A.sum(axis=1,keepdim=True)
sum_A

# %%
A / sum_A

# %%
A.cumsum(axis=0)

# %%
x = torch.arange(4,dtype=torch.float32)
y = torch.ones(4,dtype=torch.float32)
x , y , torch.dot(x,y)

# %%
torch.sum(x * y)

# %%
# x = x.to(torch.long)
A.shape,x.shape,torch.mv(A,x)

# %%
B = torch.ones(4,3,dtype=torch.float32)
A = A.to(torch.float32)
torch.mm(A,B)

# %%
u = torch.tensor([3.0,-4.0])
torch.norm(u)

# %%
torch.abs(u).sum()

# %%
torch.norm(torch.ones(4,9))
