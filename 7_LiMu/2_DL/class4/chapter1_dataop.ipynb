# %%
import torch
# 张量表示一个数值组成的数组,这个数组可能有多个维度
x = torch.arange(12)
print(x)
# 可以通过shape访问张量的形状,numel()方法可以知道张量中元素的总数
print(x.shape) 
print(x.numel())
# 要改变一个张量的形状而不改变元素数量和元素值,可以跳动reshape函数
x.reshape(3,4)# reshape并不会修改x的地址

# %%
# 使用0/1,其他常量或者从特定分布中随机采样的数字
a = torch.zeros((2,3,4))
print(a)
torch.ones((2,3,4))

# %%
# 通过提供包含数值的列表,来为所需张量中的每个元素赋予确定值
torch.tensor([1,2,3])

# %%
# 常见的标准算术运算符,都可以升级为按元素运算
x = torch.tensor([1.0,2,4,8])
y = torch.tensor([2,2,2,2])
x + y,x * y,x / y,x ** y

# %%
# 可以把多个张量连结在一起
X = torch.arange(12,dtype=torch.float32).reshape(3,4)
Y = torch.tensor([[2.0,1,4,3],[1,2,3,4],[4,3,2,1]])
torch.cat((X,Y),dim=0),torch.cat((X,Y),dim=1)

# %%
X == Y

# %%
# 对张量中的所有元素进行求和会产生一个只有一个元素的张量
X.sum()

# %%
# 即使形状不同,仍然可以通过调用广播机制来执行按元素操作
a = torch.arange(3).reshape((3,1)) 
b = torch.arange(2).reshape((1,2))
print(a,b)

print(a+b)

# %%
# 可以用[-1]选择最后一行元素,可以用[1:3]选择第二个和第三行元素
X[-1],X[1:3]

# %%
# 除读取外,还可以通过指定索引来将元素写入矩阵
X[1,2]=9
X

# %%
# 为多个元素赋值相同的值,只需要索引所有元素,然后为它们赋值
X[0:2,:]=12 # 0和1行,都赋值12
X

# %%
# 运行一些操作可能导致为新结果分配内存
before = id(X)
Y = Y+X
id(Y)==before

# %%
# 执行原地操作
Z = torch.zeros_like(Y)
print("id(Z):",id(Z))
Z[:]=X+Y
print("id(Z):",id(Z))

# %%
# 如果后续计算中没有重复使用X,也可以使用X[:]=X+Y或X+=Y来减少操作的内存开销
before =  id(X)
X+=Y
id(X)==before

# %%
# 转成numpy张量
X = torch.tensor(1)
A = X.numpy()
B = torch.tensor(A)
type(A),type(B)

# %%
# 将大小为1的张量转换为python标量
a = torch.tensor(3.5)
a,a.item(),float(a),int(a)
