# %%
import numpy as np

# %%
# 随机生成(0,1)均匀分布的数据
a = np.random.rand(5)
print(a)

# %%
a = np.random.rand(2,3)
print(a)

# %%
# 随机生成均匀分布的整数
b = np.random.randint(0,100,size=(2,3))
print(b)

# %%
# 随机生成从标准正态分布的数据
c = np.random.randn(2,5)
print(c)

# %%
print(c+5)

# %%
print(c*10+5)
